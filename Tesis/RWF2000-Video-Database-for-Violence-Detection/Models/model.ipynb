# %%
from keras.models import load_model
#from keras.optimizers import SGD
from keras.optimizers import Adam

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
adam = Adam(lr=0.01, decay=1e-6)

model = load_model('./keras_model.h5')

#model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Using TensorFlow backend.
# C:\Users\mroch\miniconda3\envs\Tesis\lib\site-packages\keras\backend\tensorflow_backend.py:3112: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if training is 1 or training is True:
# C:\Users\mroch\miniconda3\envs\Tesis\lib\site-packages\keras\backend\tensorflow_backend.py:3118: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif training is 0 or training is False:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\utils\generic_utils.py:231, in func_load(code, defaults, closure, globs)
#     230     raw_code = codecs.decode(code.encode('ascii'), 'base64')
# --> 231     code = marshal.loads(raw_code)
#     232 except (UnicodeEncodeError, binascii.Error, ValueError):
#     233     # backwards compatibility for models serialized prior to 2.1.2
#
# ValueError: bad marshal data (unknown type code)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       5 #sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#       6 adam = Adam(lr=0.01, decay=1e-6)
# ----> 8 model = load_model('./keras_model.h5')
#      10 #model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])
#      11 model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
#
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\engine\saving.py:419, in load_model(filepath, custom_objects, compile)
#     417 f = h5dict(filepath, 'r')
#     418 try:
# --> 419     model = _deserialize_model(f, custom_objects, compile)
#     420 finally:
#     421     if opened_new_file:
#
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\engine\saving.py:225, in _deserialize_model(f, custom_objects, compile)
#     223     raise ValueError('No model found in config.')
#     224 model_config = json.loads(model_config)#.decode('utf-8'))
# --> 225 model = model_from_config(model_config, custom_objects=custom_objects)
#     226 model_weights_group = f['model_weights']
#     228 if 'keras_version' in model_weights_group:
#
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\engine\saving.py:458, in model_from_config(config, custom_objects)
#     454     raise TypeError('`model_from_config` expects a dictionary, '
#     455                     'not a list. Maybe you meant to use '
#     456                     '`Sequential.from_config(config)`?')
#     457 from ..layers import deserialize
# --> 458 return deserialize(config, custom_objects=custom_objects)
#
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\layers\__init__.py:52, in deserialize(config, custom_objects)
#      50 globs['Model'] = models.Model
#      51 globs['Sequential'] = models.Sequential
# ---> 52 return deserialize_keras_object(config,
#      53                                 module_objects=globs,
#      54                                 custom_objects=custom_objects,
#      55                                 printable_module_name='layer')
#
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\utils\generic_utils.py:142, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     140 custom_objects = custom_objects or {}
#     141 if has_arg(cls.from_config, 'custom_objects'):
# --> 142     return cls.from_config(
#     143         config['config'],
#     144         custom_objects=dict(list(_GLOBAL_CUSTOM_OBJECTS.items()) +
#     145                             list(custom_objects.items())))
#     146 with CustomObjectScope(custom_objects):
#     147     return cls.from_config(config['config'])
#
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\engine\network.py:1022, in Network.from_config(cls, config, custom_objects)
#    1020 # First, we create all layers and enqueue nodes to be processed
#    1021 for layer_data in config['layers']:
# -> 1022     process_layer(layer_data)
#    1023 # Then we process nodes in order of layer depth.
#    1024 # Nodes that cannot yet be processed (if the inbound node
#    1025 # does not yet exist) are re-enqueued, and the process
#    1026 # is repeated until all nodes are processed.
#    1027 while unprocessed_nodes:
#
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\engine\network.py:1007, in Network.from_config.<locals>.process_layer(layer_data)
#    1004 # Instantiate layer.
#    1005 from ..layers import deserialize as deserialize_layer
# -> 1007 layer = deserialize_layer(layer_data,
#    1008                           custom_objects=custom_objects)
#    1009 created_layers[layer_name] = layer
#    1011 # Gather layer inputs.
#
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\layers\__init__.py:52, in deserialize(config, custom_objects)
#      50 globs['Model'] = models.Model
#      51 globs['Sequential'] = models.Sequential
# ---> 52 return deserialize_keras_object(config,
#      53                                 module_objects=globs,
#      54                                 custom_objects=custom_objects,
#      55                                 printable_module_name='layer')
#
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\utils\generic_utils.py:142, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     140 custom_objects = custom_objects or {}
#     141 if has_arg(cls.from_config, 'custom_objects'):
# --> 142     return cls.from_config(
#     143         config['config'],
#     144         custom_objects=dict(list(_GLOBAL_CUSTOM_OBJECTS.items()) +
#     145                             list(custom_objects.items())))
#     146 with CustomObjectScope(custom_objects):
#     147     return cls.from_config(config['config'])
#
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\layers\core.py:735, in Lambda.from_config(cls, config, custom_objects)
#     729     function = deserialize_keras_object(
#     730         config['function'],
#     731         custom_objects=custom_objects,
#     732         printable_module_name='function in Lambda layer')
#     733 elif function_type == 'lambda':
#     734     # Unsafe deserialization from bytecode
# --> 735     function = func_load(config['function'], globs=globs)
#     736 else:
#     737     raise TypeError('Unknown function type:', function_type)
#
# File ~\miniconda3\envs\Tesis\lib\site-packages\keras\utils\generic_utils.py:235, in func_load(code, defaults, closure, globs)
#     232 except (UnicodeEncodeError, binascii.Error, ValueError):
#     233     # backwards compatibility for models serialized prior to 2.1.2
#     234     raw_code = code.encode('raw_unicode_escape')
# --> 235     code = marshal.loads(raw_code)
#     236 if globs is None:
#     237     globs = globals()
#
# ValueError: bad marshal data (unknown type code)
